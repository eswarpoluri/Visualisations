# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
# matplotlib inline is used to bring graph into jupyter notebook. 
#for newer version of anaconda it is not required

# %%
from numpy.random import randn, randint, uniform, sample
# sample = random_sample = ranf = random = Return the next random floating point no in the range [0.0, 1.0]]

#uniform()  numpy.random.uniform(low=0.0, high=1.0, size=None) includes low, but excludes high
    # gives uniformly distrubeted random numbers in the given range and shape

# %% [markdown]
# ## Limitations of pandas, matplotlib, seaborn:
# ## intractive graphs are not possiable (showing point tip values)
# ## 2D, 3D graphs are possiable with static not zoomable
# ## plotly is advanced visuvalization lib with all these features

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
df.head()
# Out:
#                value
# 2019-06-07  0.787352
# 2019-06-08 -1.675070
# 2019-06-09 -0.977596
# 2019-06-10  0.003934
# 2019-06-11 -0.319837

# %%
df['value'] = df['value'].cumsum()  # cummulative sum will add all the values above a given cell to it
df.head()
# Out:
#                value
# 2019-06-07  0.787352
# 2019-06-08 -0.887718
# 2019-06-09 -1.865314
# 2019-06-10 -1.861380
# 2019-06-11 -2.181217

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07   -0.498926
# 2019-06-08    1.322896
# 2019-06-09    2.143403
# 2019-06-10    1.475777
# 2019-06-11    1.137697
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(5,5)) # using pandas

# %%
plt.plot(ts)

# %%
df.plot()

# %%
iris = sns.load_dataset('iris') # iris dataset is inbuilt in seaborn library. no need to import seperatly
# https://github.com/mwaskom/seaborn-data (for other data set)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind = 'bar')

# %%
df = iris.drop(['species'], axis = 1)

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind = 'bar')

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0 -1.032592 -0.663262  0.090283  0.475690
# 1 -0.458179 -2.001288 -0.975992 -1.378214
# 2 -1.906648 -0.822758 -1.222739 -0.004523
# 3  0.760194 -1.924841 -0.049596  0.577729
# 4  0.656909  1.497623  0.714346  1.387641
# 5 -1.113394  0.265549  0.665122  0.945802
# 6  2.198608 -0.641567  0.314964 -0.500444
# 7 -0.362450  1.286630  0.238579  1.138328
# 8  0.630054 -0.981726 -0.464423 -0.039545
# 9  0.079187  0.740936  1.491928 -1.165757

# %%
df.plot.bar()

# %%
df.plot(kind = 'bar')

# %%
df.plot.barh()

# %%
iris.plot.hist()
#hist: groups all unique values and put it on x-axis, on y axist count/frequnecy on each value

# %%
iris.plot(kind = 'hist')

# %%
iris.plot(kind = 'hist', stacked = False, bins = 100)
# stacked will bring all the samller value graphs fornt side to avoid hidding of overlapping data

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'b', alpha = 0.1, figsize=(10,10))
# alpha is the intensity of the color
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FBF95B1F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FBF95AD548>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001FBF9609E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FBF96444C8>]],
#       dtype=object)

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')
# c is The color intensity of each point among the range of "c"
# more c value more intensity.

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');
#df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
#df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190)
# s is the size of dots

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (10,10))

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# subplots will give all the column plots
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001FBFAC3D388>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001FBFAC70308>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001FBFACA4788>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')
# autopct: shows % value & ".2f" shows 2 decimals
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001FBFAD51448>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001FBFAD83808>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001FBFADBB408>],
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
# scatter_matrix: provide scatter graph of each column with every other column
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b') # kde - kernel density estimate
plt.show()

# %%
ts.plot.kde()

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')
# what is the purpose of andrews curves

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)
# logy: Use log scaling on y axis.

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width]
# Index: []

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)
# What is the purpose of AX

# %%
x.plot(figsize=(10,5), x_compat = True)
# what is the purpose of x_compat

# %%
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001FBFBE56AC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001FBFBE56FC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001FBFBE93DC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001FBFBEC5F88>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()

# %%
from descartes import PolygonPatch

# %%
import geopandas as gpd

# %%
map_df = gpd.read_file('London_Borough_Excluding_MHW.shp')
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
map_df.plot()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: London_Borough_Excluding_MHW.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-63-a3f2844261f5> in <module>
# ----> 1 map_df = gpd.read_file('London_Borough_Excluding_MHW.shp')
#       2 # check data type so we can see that this is not a normal dataframe, but a GEOdataframe
#       3 map_df.head()
#       4 map_df.plot()
#
# ~\Anaconda3\lib\site-packages\geopandas\io\file.py in read_file(filename, bbox, **kwargs)
#      74
#      75     with fiona_env():
# ---> 76         with reader(path_or_bytes, **kwargs) as features:
#      77
#      78             # In a future Fiona release the crs attribute of features will
#
# ~\Anaconda3\lib\site-packages\fiona\env.py in wrapper(*args, **kwargs)
#     394     def wrapper(*args, **kwargs):
#     395         if local._env:
# --> 396             return f(*args, **kwargs)
#     397         else:
#     398             if isinstance(args[0], str):
#
# ~\Anaconda3\lib\site-packages\fiona\__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     251         if mode in ('a', 'r'):
#     252             c = Collection(path, mode, driver=driver, encoding=encoding,
# --> 253                            layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     254         elif mode == 'w':
#     255             if schema:
#
# ~\Anaconda3\lib\site-packages\fiona\collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     157             if self.mode == 'r':
#     158                 self.session = Session()
# --> 159                 self.session.start(self, **kwargs)
#     160             elif self.mode in ('a', 'w'):
#     161                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# DriverError: London_Borough_Excluding_MHW.shp: No such file or directory

# %%
map_df
